# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# 구글 드라이브와 연동하는 방법 입니다. 
# Google File Drive Stream 접근을 허용해야 합니다.
from google.colab import auth
auth.authenticate_user()

# 구글 드라이브 mount 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# 1. 홈 디렉토리에 datasets 폴더 생성 후, 그 안에 cats_and_dogs_small 폴더를 생성 합니다.
# 2. cats_and_dogs_small 안에 train, test, validation 폴더가 위치 하도록 압축을 풉니다.
# %cd gdrive/My Drive/datasets/cats_and_dogs_small
# Out:
# /content/gdrive/My Drive/datasets/cats_and_dogs_small

# %%
# !ls
# Out:
# test  train  validation

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/datasets/cats_and_dogs_small

# %%
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator

# 모든 이미지를 1/255로 스케일을 조정합니다
# (batch, height, width, channel)
# Numpy N-dims Array (60000, 28, 28, 1) batch_size = 4 --> (4, 28, 28, 1)
# 0 ~255 /255 -> 0 ~ 1
# Image Augmentation

train_datagen = ImageDataGenerator(rescale = 1./255, 
                                   shear_range = 0.2, 
                                   zoom_range = 0.2, 
                                   horizontal_flip = True)
# Batch_size = 4 -> (4, 28, 28, 1)
# Augmentation: Shear, Zoom, Flip

test_datagen = ImageDataGenerator(rescale=1./255)
# Augmentation X , Scale [0~1]

base_dir = '/content/gdrive/My Drive/datasets/cats_and_dogs_small'

train_dir = os.path.join(base_dir, 'train')
# '/content/gdrive/My Drive/datasets/cats_and_dogs_small/train'

test_dir  = os.path.join(base_dir, 'test')
# '/content/gdrive/My Drive/datasets/cats_and_dogs_small/test'

validation_dir = os.path.join(base_dir, 'validation')
# '/content/gdrive/My Drive/datasets/cats_and_dogs_small/validation'

# Batch 
# (360, 240, 3)  --> (224, 224, 3) 
# (1024, 1280, 3) --> (224, 224, 3)
# (B, W, H , C)
# (2, 224, 224, 3)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(224, 224),
        batch_size=4,
        # binary_crossentropy 손실을 사용하기 때문에 이진 레이블이 필요합니다
        class_mode='categorical')

# softmax activation -> categorical_crossentropy, one-hot encoding
# sigmoid activation -> binary_crossentropy 


# binary cats: 0, dogs: 1
# categorical cats: [1, 0] dogs: [0, 1]

# Target index {'cats': 0, 'dogs': 1}
# [[1, 0]    --> cat
#  [0, 1]    --> dog
#  [1, 0]    --> cat
#  [1, 0]]   --> cat

# Source (4, 224, 224, 3)
# Target (4, 2)


# Binary 0 ~ 1
# Categorical [1, 0] == 0
#             [0, 1] == 1

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(224, 224),
        batch_size=4,
        class_mode='categorical')

# source (4, 224, 224, 3)
# target (4, 2)
# Out:
# Found 121 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.

# %%
for data_batch, labels_batch in train_generator:
    print ('Batch size:', data_batch.shape)
    print ('Label size:', labels_batch.shape)
    break

# One-Hot encoding Example
# 2개 0, 1
# 0: [1, 0]
# 1: [0, 1]
# Out:
# Batch size: (4, 224, 224, 3)
# Label size: (4, 2)

# %%
print (train_generator.class_indices)
# Out:
# {'cats': 0, 'dogs': 1}

# %%
#  This code cell shows how to utilize VGG16 model by combining Dense layer at the end of the network 
from keras.layers import Input, Dense, GlobalAveragePooling2D, Flatten
from keras.models import Model

from keras.applications.vgg16 import VGG16
from keras import layers
from keras import models

VGGNet = VGG16()
VGGNet.summary()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 40s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
# We will not update VGG pre-trained model, only added Dense layers will be trained from the scratch
for layer in VGGNet.layers:
  layer.trainable = False
  
Feature_Flatten = VGGNet.get_layer('flatten').output

dense = Dense(256, name='encoding', activation='relu')(Feature_Flatten)
predictions = Dense(2, activation='softmax', name="prediction")(dense)

New_VGGmodel = Model(inputs=VGGNet.input, outputs=predictions)
New_VGGmodel.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

New_VGGmodel.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# encoding (Dense)             (None, 256)               6422784
# _________________________________________________________________
# prediction (Dense)           (None, 2)                 514
# =================================================================
# Total params: 21,137,986
# Trainable params: 6,423,298
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
history = New_VGGmodel.fit_generator(
    train_generator,
    # validation_data=validation_generator, 
    # validation_steps=5,
    # 20장 / batch_size 4 = 5
    # 60장 / batch_size 4 = 15
    steps_per_epoch=500,

    epochs=30
)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/30
# 500/500 [==============================] - 113s 227ms/step - loss: 0.7261 - accuracy: 0.8707
# Epoch 2/30
# 500/500 [==============================] - 34s 67ms/step - loss: 0.0836 - accuracy: 0.9918
# Epoch 3/30
# 500/500 [==============================] - 34s 69ms/step - loss: 0.0646 - accuracy: 0.9944
# Epoch 4/30
# 500/500 [==============================] - 34s 68ms/step - loss: 0.0584 - accuracy: 0.9949
# Epoch 5/30
# 500/500 [==============================] - 34s 68ms/step - loss: 0.0649 - accuracy: 0.9933
# Epoch 6/30
# 500/500 [==============================] - 34s 68ms/step - loss: 0.0290 - accuracy: 0.9985
# Epoch 7/30
# 500/500 [==============================] - 34s 67ms/step - loss: 0.0162 - accuracy: 0.9979
# Epoch 8/30
# 500/500 [==============================] - 34s 69ms/step - loss: 0.0246 - accuracy: 0.9969
# Epoch 9/30
# 500/500 [==============================] - 35s 69ms/step - loss: 0.0183 - accuracy: 0.9990
# Epoch 10/30
# 500/500 [==============================] - 35s 70ms/step - loss: 0.0192 - accuracy: 0.9979
# Epoch 11/30
# 500/500 [==============================] - 35s 71ms/step - loss: 0.0385 - accuracy: 0.9985
# Epoch 12/30
# 500/500 [==============================] - 36s 72ms/step - loss: 0.0067 - accuracy: 0.9985
# Epoch 13/30
# 500/500 [==============================] - 36s 72ms/step - loss: 6.0295e-05 - accuracy: 1.0000
# Epoch 14/30
# 500/500 [==============================] - 36s 72ms/step - loss: 1.1922e-10 - accuracy: 1.0000
# Epoch 15/30
# 500/500 [==============================] - 36s 73ms/step - loss: 2.2038e-04 - accuracy: 1.0000
# Epoch 16/30
# 500/500 [==============================] - 37s 73ms/step - loss: 0.0200 - accuracy: 0.9990
# Epoch 17/30
# 500/500 [==============================] - 37s 73ms/step - loss: 5.9608e-10 - accuracy: 1.0000
# Epoch 18/30
# 500/500 [==============================] - 37s 73ms/step - loss: 2.8053e-08 - accuracy: 1.0000
# Epoch 19/30
# 500/500 [==============================] - 37s 73ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 20/30
# 500/500 [==============================] - 36s 73ms/step - loss: 0.0011 - accuracy: 0.9990
# Epoch 21/30
# 500/500 [==============================] - 36s 72ms/step - loss: 0.0039 - accuracy: 0.9995
# Epoch 22/30
# 500/500 [==============================] - 36s 71ms/step - loss: 0.0115 - accuracy: 0.9980
# Epoch 23/30
# 500/500 [==============================] - 36s 71ms/step - loss: 2.3843e-10 - accuracy: 1.0000
# Epoch 24/30
# 500/500 [==============================] - 36s 71ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 25/30
# 500/500 [==============================] - 36s 72ms/step - loss: 0.0131 - accuracy: 0.9985
# Epoch 26/30
# 500/500 [==============================] - 36s 71ms/step - loss: 8.5238e-09 - accuracy: 1.0000
# Epoch 27/30
# 500/500 [==============================] - 36s 72ms/step - loss: 2.9105e-06 - accuracy: 1.0000
# Epoch 28/30
# 500/500 [==============================] - 36s 72ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 29/30
# 500/500 [==============================] - 36s 72ms/step - loss: 4.7686e-10 - accuracy: 1.0000
# Epoch 30/30
# 500/500 [==============================] - 36s 72ms/step - loss: 0.0000e+00 - accuracy: 1.0000

# %%
print (train_generator.class_indices)
# Out:
# {'cats': 0, 'dogs': 1}

# %%
pip install flickrapi
# Out:
# Collecting flickrapi
#   Downloading https://files.pythonhosted.org/packages/76/d7/291b7f0f02cf0f59460f7bcc15192905b4c61e13b9fb9263ee86b0a5f647/flickrapi-2.4.0-py2.py3-none-any.whl
# Collecting requests-toolbelt>=0.3.1
#   Downloading https://files.pythonhosted.org/packages/60/ef/7681134338fc097acef8d9b2f8abe0458e4d87559c689a8c306d0957ece5/requests_toolbelt-0.9.1-py2.py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 6.6MB/s
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from flickrapi) (1.3.0)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from flickrapi) (1.15.0)
# Requirement already satisfied: requests>=2.2.1 in /usr/local/lib/python3.6/dist-packages (from flickrapi) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.4.0->flickrapi) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->flickrapi) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->flickrapi) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->flickrapi) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->flickrapi) (3.0.4)
# Installing collected packages: requests-toolbelt, flickrapi
# Successfully installed flickrapi-2.4.0 requests-toolbelt-0.9.1

# %%
from flickrapi import FlickrAPI

FLICKER_KEY = '505e8c2b05e8b5aa51766a43fc4bc7a7'
FLICKER_SECRET = '46b3ef2f43b04ac6'

flickr = FlickrAPI(FLICKER_KEY, FLICKER_SECRET, format='parsed-json')
cats = flickr.photos.search(text='puppy', per_page=5, extras='url_s')
photos = cats['photos']

# %%
photos
# Out:
# {'page': 1,
#  'pages': 39080,
#  'perpage': 5,
#  'photo': [{'farm': 66,
#    'height_s': 192,
#    'id': '50322595316',
#    'isfamily': 0,
#    'isfriend': 0,
#    'ispublic': 1,
#    'owner': '189241372@N03',
#    'secret': '86c1a2ab25',
#    'server': '65535',
#    'title': 'Cavalier King Charles Spaniel Puppies',
#    'url_s': 'https://live.staticflickr.com/65535/50322595316_86c1a2ab25_m.jpg',
#    'width_s': 240},
#   {'farm': 66,
#    'height_s': 240,
#    'id': '50321686188',
#    'isfamily': 0,
#    'isfriend': 0,
#    'ispublic': 1,
#    'owner': '67803931@N00',
#    'secret': '79e2183aa4',
#    'server': '65535',
#    'title': 'Luke',
#    'url_s': 'https://live.staticflickr.com/65535/50321686188_79e2183aa4_m.jpg',
#    'width_s': 240},
#   {'farm': 66,
#    'height_s': 180,
#    'id': '50321669288',
#    'isfamily': 0,
#    'isfriend': 0,
#    'ispublic': 1,
#    'owner': '125850056@N05',
#    'secret': '7aea30b412',
#    'server': '65535',
#    'title': 'Tired puppy',
#    'url_s': 'https://live.staticflickr.com/65535/50321669288_7aea30b412_m.jpg',
#    'width_s': 240},
#   {'farm': 66,
#    'height_s': 180,
#    'id': '50322489152',
#    'isfamily': 0,
#    'isfriend': 0,
#    'ispublic': 1,
#    'owner': '12082985@N00',
#    'secret': '3fa7c78ddd',
#    'server': '65535',
#    'title': 'DSCF2119',
#    'url_s': 'https://live.staticflickr.com/65535/50322489152_3fa7c78ddd_m.jpg',
#    'width_s': 240},
#   {'farm': 66,
#    'height_s': 240,
#    'id': '50322310751',
#    'isfamily': 0,
#    'isfriend': 0,
#    'ispublic': 1,
#    'owner': '12082985@N00',
#    'secret': '197b213512',
#    'server': '65535',
#    'title': 'DSCF2122',
#    'url_s': 'https://live.staticflickr.com/65535/50322310751_197b213512_m.jpg',
#    'width_s': 180}],
#  'total': '195396'}

# %%
# import the necessary packages
import numpy as np
import urllib
import cv2

def url_to_image(url):
  resp = urllib.request.urlopen(url)
  image = np.asarray(bytearray(resp.read()), dtype="uint8")
  image = cv2.imdecode(image, cv2.IMREAD_COLOR)

  return image

# %%
from google.colab.patches import cv2_imshow

image_original_url = photos['photo'][1]['url_s']

image_temp = url_to_image(image_original_url)
cv2_imshow(image_temp)
# Out:
# <PIL.Image.Image image mode=RGB size=240x240 at 0x7FA0C8820C88>

# %%
image_original_url
# Out:
# 'https://live.staticflickr.com/65535/50044923033_9d43ac4d53_m.jpg'

# %%
# 4D-tensor(B, H, W, C) -> (1, 224, 224, 3)
image_temp.shape
# Out:
# (240, 240, 3)

# %%
resized_image = cv2.resize(image_temp, (224, 224))
print (resized_image.shape)
# Out:
# (224, 224, 3)

# %%
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FA0C88202E8>

# %%
resized_image = np.expand_dims(resized_image, axis=0)
print (resized_image.shape)
# Out:
# (1, 224, 224, 3)

# %%
result = New_VGGmodel.predict(resized_image)

# %%
result
# Out:
# array([[0., 1.]], dtype=float32)

# %%
np.argmax(result)
# Out:
# 1

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/datasets/cats_and_dogs_small

# %%
New_VGGmodel.save('newvgg_puppy.h5')

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
loss = history.history['loss']

epochs = range(1, len(acc) + 1)

# ‘bo’는 파란색 점을 의미합니다
plt.plot(epochs, loss, 'bo', label='Training loss')
# ‘b’는 파란색 실선을 의미합니다
# plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
